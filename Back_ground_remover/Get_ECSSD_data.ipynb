# %% [markdown]
# #Download ECSSD Dataset

# %%
# !wget http://www.cse.cuhk.edu.hk/leojia/projects/hsaliency/data/ECSSD/images.zip
# Out:
# --2025-07-12 11:37:32--  http://www.cse.cuhk.edu.hk/leojia/projects/hsaliency/data/ECSSD/images.zip
# Resolving www.cse.cuhk.edu.hk (www.cse.cuhk.edu.hk)... 137.189.91.192
# Connecting to www.cse.cuhk.edu.hk (www.cse.cuhk.edu.hk)|137.189.91.192|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67766979 (65M) [application/zip]
# Saving to: ‘images.zip’
#
# images.zip          100%[===================>]  64.63M  13.7MB/s    in 12s
#
# 2025-07-12 11:37:46 (5.42 MB/s) - ‘images.zip’ saved [67766979/67766979]

# %%
# !wget http://www.cse.cuhk.edu.hk/leojia/projects/hsaliency/data/ECSSD/ground_truth_mask.zip
# Out:
# --2025-07-12 11:38:11--  http://www.cse.cuhk.edu.hk/leojia/projects/hsaliency/data/ECSSD/ground_truth_mask.zip
# Resolving www.cse.cuhk.edu.hk (www.cse.cuhk.edu.hk)... 137.189.91.192
# Connecting to www.cse.cuhk.edu.hk (www.cse.cuhk.edu.hk)|137.189.91.192|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1571109 (1.5M) [application/zip]
# Saving to: ‘ground_truth_mask.zip’
#
# ground_truth_mask.z 100%[===================>]   1.50M   447KB/s    in 3.4s
#
# 2025-07-12 11:38:16 (447 KB/s) - ‘ground_truth_mask.zip’ saved [1571109/1571109]

# %% [markdown]
# # Unzip the data

# %%
# !unzip images.zip
# Out:
# Archive:  images.zip
#   inflating: images/0001.jpg
#   inflating: images/0002.jpg
#   inflating: images/0003.jpg
#   inflating: images/0004.jpg
#   inflating: images/0005.jpg
#   inflating: images/0006.jpg
#   inflating: images/0007.jpg
#   inflating: images/0008.jpg
#   inflating: images/0009.jpg
#   inflating: images/0010.jpg
#   inflating: images/0011.jpg
#   inflating: images/0012.jpg
#   inflating: images/0013.jpg
#   inflating: images/0014.jpg
#   inflating: images/0015.jpg
#   inflating: images/0016.jpg
#   inflating: images/0017.jpg
#   inflating: images/0018.jpg
#   inflating: images/0019.jpg
#   inflating: images/0020.jpg
#   inflating: images/0021.jpg
#   inflating: images/0022.jpg
#   inflating: images/0023.jpg
#   inflating: images/0024.jpg
#   inflating: images/0025.jpg
#   inflating: images/0026.jpg
#   inflating: images/0027.jpg
#   inflating: images/0028.jpg
#   inflating: images/0029.jpg
#   inflating: images/0030.jpg
#   inflating: images/0031.jpg
# ...

# %%
# !unzip ground_truth_mask.zip
# Out:
# Archive:  ground_truth_mask.zip
#    creating: ground_truth_mask/
#   inflating: ground_truth_mask/0001.png
#   inflating: ground_truth_mask/0002.png
#   inflating: ground_truth_mask/0003.png
#   inflating: ground_truth_mask/0004.png
#   inflating: ground_truth_mask/0005.png
#  extracting: ground_truth_mask/0006.png
#  extracting: ground_truth_mask/0007.png
#   inflating: ground_truth_mask/0008.png
#  extracting: ground_truth_mask/0009.png
#  extracting: ground_truth_mask/0010.png
#   inflating: ground_truth_mask/0011.png
#   inflating: ground_truth_mask/0012.png
#   inflating: ground_truth_mask/0013.png
#   inflating: ground_truth_mask/0014.png
#   inflating: ground_truth_mask/0015.png
#   inflating: ground_truth_mask/0016.png
#   inflating: ground_truth_mask/0017.png
#   inflating: ground_truth_mask/0018.png
#   inflating: ground_truth_mask/0019.png
#  extracting: ground_truth_mask/0020.png
#   inflating: ground_truth_mask/0021.png
#   inflating: ground_truth_mask/0022.png
# ...

# %% [markdown]
# #Move to the reuired folder

# %%
# !mv /content/images/* "/content/drive/MyDrive/Colab Notebooks/Computer Vision/ECSSD_Dataset/Images"

# %%
# !mv /content/ground_truth_mask/* "/content/drive/MyDrive/Colab Notebooks/Computer Vision/ECSSD_Dataset/Masks"
